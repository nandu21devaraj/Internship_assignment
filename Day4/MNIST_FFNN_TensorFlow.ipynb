# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = (tf.keras.datasets.mnist.load_data())

train_images = train_images.astype("float32") / 255.0
test_images = test_images.astype("float32") / 255.0

train_images = train_images.reshape((60000, 28 * 28))
test_images = test_images.reshape((10000, 28 * 28))

# %%
model = models.Sequential([
    layers.Dense(1024, activation='swish', kernel_regularizer=regularizers.l2(1e-4), input_shape=(784,)),
    layers.BatchNormalization(),
    layers.Dropout(0.4),

    layers.Dense(512, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(256, activation='swish', kernel_regularizer=regularizers.l2(1e-4)),
    layers.BatchNormalization(),
    layers.Dropout(0.1),

    layers.Dense(10, activation='softmax')
])
# Out:
# c:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
plt.figure(figsize=(10, 5))
for i in range(20):
    plt.subplot(4, 5, i + 1)
    plt.imshow(train_images[i].reshape(28, 28), cmap="gray")
    plt.title(f"Label: {train_labels[i]}")
    plt.axis("off")
plt.suptitle("Sample MNIST Images with Labels", y=1.02)
plt.tight_layout()
plt.show()

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 1024)           │       803,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,469,706 (5.61 MB)
#  Trainable params: 1,466,122 (5.59 MB)
#  Non-trainable params: 3,584 (14.00 KB)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-5, verbose=1)

# %%
train_labels_cat = to_categorical(train_labels, num_classes=10)

history = model.fit(
    train_images, train_labels_cat,
    epochs=30,
    batch_size=128,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8767 - loss: 0.5744 - val_accuracy: 0.9712 - val_loss: 0.2682 - learning_rate: 0.0010
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9600 - loss: 0.2935 - val_accuracy: 0.9775 - val_loss: 0.2289 - learning_rate: 0.0010
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9689 - loss: 0.2506 - val_accuracy: 0.9798 - val_loss: 0.2171 - learning_rate: 0.0010
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9734 - loss: 0.2280 - val_accuracy: 0.9782 - val_loss: 0.2088 - learning_rate: 0.0010
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9773 - loss: 0.2114 - val_accuracy: 0.9812 - val_loss: 0.1993 - learning_rate: 0.0010
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9772 - loss: 0.2033 - val_accuracy: 0.9802 - val_loss: 0.1983 - learning_rate: 0.0010
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9801 - loss: 0.1950 - val_accuracy: 0.9780 - val_loss: 0.2036 - learning_rate: 0.0010
# Epoch 8/30
# 420/422 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9804 - loss: 0.1880
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9804 - loss: 0.1880 - val_accuracy: 0.9815 - val_loss: 0.1989 - learning_rate: 0.0010
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9846 - loss: 0.1675 - val_accuracy: 0.9850 - val_loss: 0.1698 - learning_rate: 5.0000e-04
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9880 - loss: 0.1466 - val_accuracy: 0.9842 - val_loss: 0.1641 - learning_rate: 5.0000e-04
# Epoch 11/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9886 - loss: 0.1364 - val_accuracy: 0.9847 - val_loss: 0.1563 - learning_rate: 5.0000e-04
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9895 - loss: 0.1304 - val_accuracy: 0.9828 - val_loss: 0.1628 - learning_rate: 5.0000e-04
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9891 - loss: 0.1267 - val_accuracy: 0.9858 - val_loss: 0.1438 - learning_rate: 5.0000e-04
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9878 - loss: 0.1271 - val_accuracy: 0.9832 - val_loss: 0.1498 - learning_rate: 5.0000e-04
# Epoch 15/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9891 - loss: 0.1219
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9891 - loss: 0.1219 - val_accuracy: 0.9807 - val_loss: 0.1569 - learning_rate: 5.0000e-04
# Epoch 16/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9917 - loss: 0.1125 - val_accuracy: 0.9888 - val_loss: 0.1310 - learning_rate: 2.5000e-04
# Epoch 17/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9935 - loss: 0.1018 - val_accuracy: 0.9868 - val_loss: 0.1270 - learning_rate: 2.5000e-04
# Epoch 18/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9941 - loss: 0.0948 - val_accuracy: 0.9875 - val_loss: 0.1228 - learning_rate: 2.5000e-04
# Epoch 19/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9951 - loss: 0.0879 - val_accuracy: 0.9888 - val_loss: 0.1207 - learning_rate: 2.5000e-04
# Epoch 20/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9949 - loss: 0.0853 - val_accuracy: 0.9872 - val_loss: 0.1166 - learning_rate: 2.5000e-04
# Epoch 21/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9929 - loss: 0.0890 - val_accuracy: 0.9857 - val_loss: 0.1204 - learning_rate: 2.5000e-04
# Epoch 22/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9943 - loss: 0.0825 - val_accuracy: 0.9873 - val_loss: 0.1137 - learning_rate: 2.5000e-04
# Epoch 23/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9941 - loss: 0.0808 - val_accuracy: 0.9882 - val_loss: 0.1148 - learning_rate: 2.5000e-04
# Epoch 24/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9947 - loss: 0.0783
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9947 - loss: 0.0783 - val_accuracy: 0.9863 - val_loss: 0.1157 - learning_rate: 2.5000e-04
# Epoch 25/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9943 - loss: 0.0767 - val_accuracy: 0.9878 - val_loss: 0.1087 - learning_rate: 1.2500e-04
# Epoch 26/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9962 - loss: 0.0689 - val_accuracy: 0.9873 - val_loss: 0.1108 - learning_rate: 1.2500e-04
# Epoch 27/30
# 419/422 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9964 - loss: 0.0674
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9964 - loss: 0.0674 - val_accuracy: 0.9887 - val_loss: 0.1094 - learning_rate: 1.2500e-04
# Epoch 28/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9969 - loss: 0.0643 - val_accuracy: 0.9902 - val_loss: 0.1050 - learning_rate: 6.2500e-05
# Epoch 29/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9974 - loss: 0.0624 - val_accuracy: 0.9888 - val_loss: 0.1040 - learning_rate: 6.2500e-05
# Epoch 30/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9979 - loss: 0.0596 - val_accuracy: 0.9905 - val_loss: 0.1024 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 30.

# %%
test_labels_cat = to_categorical(test_labels, num_classes=10)
test_loss, test_acc = model.evaluate(test_images, test_labels_cat)
print(f"\n✅ Test Accuracy: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9849 - loss: 0.1085
#
# ✅ Test Accuracy: 0.9884

# %%
# Plotting training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
predictions = model.predict(test_images)
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(test_images[i].reshape(28, 28), cmap='gray')
    pred_label = np.argmax(predictions[i])
    true_label = test_labels[i]
    color = 'green' if pred_label == true_label else 'red'
    plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
